# %% [markdown]
# # Defensive Programming
#
# ---
#
# ### Objectives
#
# - Explain what an assertion is
# - Add assertions that check the program's state is correct
# - Correctly add precondition and postcondition assertions to functions
# - Explain what test-driven development is, and use it when creating new functions
# - Explain why variables should be initialized using actual data values rather than arbitrary constants
#
# ---

# %% [markdown]
# #### Background
#
# - Our previous lessons introduced basic programming tools
# - We need to learn how to verify program correctness
# - To achieve this, we need to:
#   1. Write programs that check their own operation
#   2. Write and run tests for widely-used functions
#   3. Make sure we know what "correct" actually means
#
# ---

# %% [markdown]
# #### Assertions
#
# - Defensive programming assumes mistakes will happen
# - Assertions check if something is true at a certain point in a program
# - If assertion is false, Python halts the program and prints an error message
#
# ---

# %%
def fahr_to_celcius(temp):
    assert type(temp) != str and \
        type(temp) != bool, "Input temp is not a float"
    celcius = ((temp - 32) * (5/9))
    return celcius

# %%
fahr_to_celcius(True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 fahr_to_celcius(True)
#
# Cell In[21], line 2, in fahr_to_celcius(temp)
#       1 def fahr_to_celcius(temp):
# ----> 2     assert type(temp) != str and \
#       3         type(temp) != bool, "Input temp is not a float"
#       4     celcius = ((temp - 32) * (5/9))
#       5     return celcius
#
# AssertionError: Input temp is not a float

# %%
# Example code for assertion: Finding the sum of positive numbers in a list

numbers = [1.5, 2.3, 0.7, -0.001, 4.4]
total = 0.0
# more code
for num in numbers:
    # assert num > 0.0, "Data should only contain positive numbers " + str(num)
    if num > 0:
        total += num
    else:
        print("Data should only contain positive numbers " + str(num))

print("Total is:", total)
# Out:
# Data should only contain positive numbers -0.001
# Total is: 8.9

# %%
numbers = [1.5, 2.3, 0.7, -0.001, 4.4]
total = 0.0
# more code
for num in numbers:
    assert num > 0.0, "Data should only contain positive numbers " + str(num)
    total += num

print("Total is:", total)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[31], line 5
#       3 # more code
#       4 for num in numbers:
# ----> 5     assert num > 0.0, "Data should only contain positive numbers " + str(num)
#       6     total += num
#       7 print("Total is:", total)
#
# AssertionError: Data should only contain positive numbers -0.001

# %% [markdown]
# #### Types of Assertions
#
# 1. Precondition: Must be true at the start of a function
# 2. Postcondition: Function guarantees is true when it finishes
# 3. Invariant: Always true at a particular point inside code

# %% [markdown]
# #### Assertion Example: Normalizing a Rectangle
#
# ```python
# def normalize_rectangle(rect):
#     assert len(rect) == 4, 'Rectangles must contain 4 coordinates'
#     x0, y0, x1, y1 = rect
#     assert x0 < x1, 'Invalid X coordinates'
#     assert y0 < y1, 'Invalid Y coordinates'
#     # ... (rest of the function)
#     assert 0 < upper_x <= 1.0, 'Calculated upper X coordinate invalid'
#     assert 0 < upper_y <= 1.0, 'Calculated upper Y coordinate invalid'
#     return (0, 0, upper_x, upper_y)
# ```

# %%
def normalize_rectangle(rect):
    # min_x, min_y, max_x, max_y
    assert len(rect) == 4, 'Rectangles must contain 4 coordinates'
    x0, y0, x1, y1 = rect
    assert x0 < x1, 'Invalid X coordinates'
    assert y0 < y1, 'Invalid Y coordinates'

    dx = x1 - x0
    dy = y1 - y0
    if dx > dy:
        scaled = dx / dy
        upper_x, upper_y = 1.0, scaled
    else:
        scaled = dx / dy
        upper_x, upper_y = scaled, 1.0
    
    assert 0 < upper_x <= 1.0, 'Calculated upper X coordinate invalid'
    assert 0 < upper_y <= 1.0, 'Calculated upper Y coordinate invalid'
    return (0, 0, upper_x, upper_y)

# %%
print(normalize_rectangle((0.0, 1.0, 2.0)))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 print(normalize_rectangle((0.0, 1.0, 2.0)))
#
# Cell In[32], line 3, in normalize_rectangle(rect)
#       1 def normalize_rectangle(rect):
#       2     # min_x, min_y, max_x, max_y
# ----> 3     assert len(rect) == 4, 'Rectangles must contain 4 coordinates'
#       4     x0, y0, x1, y1 = rect
#       5     assert x0 < x1, 'Invalid X coordinates'
#
# AssertionError: Rectangles must contain 4 coordinates

# %%
# Assertion fails because min_x is greater than the max_x
print(normalize_rectangle((4.0, 2.0, 1.0, 5.0)))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Assertion fails because min_x is greater than the max_x
# ----> 2 print(normalize_rectangle((4.0, 2.0, 1.0, 5.0)))
#
# Cell In[32], line 5, in normalize_rectangle(rect)
#       3 assert len(rect) == 4, 'Rectangles must contain 4 coordinates'
#       4 x0, y0, x1, y1 = rect
# ----> 5 assert x0 < x1, 'Invalid X coordinates'
#       6 assert y0 < y1, 'Invalid Y coordinates'
#       8 dx = x1 - x0
#
# AssertionError: Invalid X coordinates

# %%
# Valid coordinates
print(
    normalize_rectangle(
        (0.0, 0.0, 1.0, 5.0)
    )
)
# Out:
# (0, 0, 0.2, 1.0)

# %% [markdown]
# #### Benefits of Assertions
#
# - Catch errors early
# - Help understand programs
# - Fail early, fail often
# - Turn bugs into assertions or tests
#
#
# ---

# %% [markdown]
# #### Test-Driven Development (TDD)
#
# 1. Write short functions for each test
# 2. Write the main function that should pass those tests
# 3. Fix and re-run tests if wrong answers are produced
#
#
# #### Benefits of TDD
#
# - Avoids confirmation bias
# - Helps define function behavior
# - Implicitly defines input and output formats
# ---

# %%
# Example code

def range_overlap(ranges):
    pass

# Test cases
assert range_overlap([()]) == None
assert range_overlap([ (0.0, 1.0) ]) == (0.0, 1.0)
assert range_overlap([ (2.0, 3.0), (2.0, 4.0) ]) == (2.0, 3.0)
assert range_overlap([ (0.0, 1.0), (0.0, 2.0), (-1.0, 1.0) ]) == (0.0, 1.0)

# %% [markdown]
# #### Handling Edge Cases
#
# - Consider cases where ranges don't overlap
# - Define behavior for touching endpoints
# - Use `None` for no overlap

# %% [markdown]
# #### Final Range Overlap Implementation
#
# Read to understand the implementation of range overlap function

# %%
def range_overlap(ranges):
    """Return common overlap among a set of [left, right] ranges."""
    max_left = 0.0
    min_right = 1.0
    for (left, right) in ranges:
        max_left = max(max_left, left)
        min_right = min(min_right, right)
    return (max_left, min_right)

# %% [markdown]
# #### Test function for the `range_overlap()`

# %%
# Write the test function

def test_range_overlap():
    assert range_overlap([ (0.0, 1.0), (5.0, 6.0) ]) == None
    assert range_overlap([ (0.0, 1.0), (1.0, 2.0) ]) == None
    assert range_overlap([ (0.0, 1.0) ]) == (0.0, 1.0)
    assert range_overlap([ (2.0, 3.0), (2.0, 4.0) ]) == (2.0, 3.0)
    assert range_overlap([ (0.0, 1.0), (0.0, 2.0), (-1.0, 1.0) ]) == (0.0, 1.0)
    assert range_overlap([]) == None


test_range_overlap()

# %% [markdown]
# ### Exercises
#
# ---

# %% [markdown]
# #### Exercise 1: Pre- and Post-Conditions
#
# **Task:**
# Write pre-conditions and post-conditions for an `average` function that calculates the average of numbers in a NumPy array.
#
# **Steps:**
# 1. Define pre- and post-conditions
# 2. Compare with your neighbor's conditions
#
# Can you think of a function that will pass your tests but not your neighbor's, or vice versa?

# %%
# Solution code

# %% [markdown]
# #### Exercise 2: Testing Assertions
#
# Given Function:

# %%
def get_total_cars(values):
    assert len(values) > 0
    for element in values:
        assert int(element)
    values = [int(element) for element in values]
    total = sum(values)
    assert total > 0

# %% [markdown]
# 1. Explain what each assertion in the function checks
# 2. For each assertion, give an example of input that will make it fail

# %%
# Example inputs

# %% [markdown]
# Hint:
#
# ```python
#
# get_total_cars([1, 2, 3, 4])  # Works correctly
#
# get_total_cars(['a', 'b', 'c'])  # Raises ValueError
# ```
#
# Think about why the second example fails and what other inputs might cause issues.
